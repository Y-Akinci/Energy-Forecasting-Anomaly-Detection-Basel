# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path
import seaborn as sns

# %%
root_directory = os.path.dirname(os.getcwd())
print(root_directory)

data_path_15min = os.path.join(root_directory, "Data", "Merged Data", "merged_strom_meteo_15min.csv")
data_path_30min = os.path.join(root_directory, "Data", "Merged Data", "merged_strom_meteo_30min.csv")

dataset_15min_intervall = pd.read_csv(data_path_15min, sep=";", decimal=",", encoding="latin1")
dataset_30min_intervall = pd.read_csv(data_path_30min, sep=";", decimal=",", encoding="latin1")
# Out:
# c:\Users\Kerem Akkaya\Python Project\Energy-Forecasting-Anomaly-Detection-Basel
# C:\Users\Kerem Akkaya\AppData\Local\Temp\ipykernel_28612\3289073849.py:7: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset_15min_intervall = pd.read_csv(data_path_15min, sep=";", decimal=",", encoding="latin1")
# C:\Users\Kerem Akkaya\AppData\Local\Temp\ipykernel_28612\3289073849.py:8: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset_30min_intervall = pd.read_csv(data_path_30min, sep=";", decimal=",", encoding="latin1")

# %%
# Zeilen löschen, welche keinen Wert bei der Zielvariable "Stromverbrauch" haben
dataset_15min_intervall.dropna(subset="Stromverbrauch", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Zeilen löschen, welche keinen Wert bei der Zielvariable "Stromverbrauch" haben
# ----> 2 dataset_15min_intervall.dropna(subset="Stromverbrauch", inplace=True)
#
# NameError: name 'dataset_15min_intervall' is not defined

# %% [markdown]
# ### Datentypen

# %%
# Datum und Zeitwert in datetime umwandeln
dataset_15min_intervall["DateTime"] = pd.to_datetime(dataset_15min_intervall["DateTime"], utc=True)

# "Date" und "Time" als eigene Spalten erstellen
dataset_15min_intervall["Date"] = dataset_15min_intervall["DateTime"].dt.strftime("%Y-%m-%d")
dataset_15min_intervall["Time"] = dataset_15min_intervall["DateTime"].dt.strftime("%H-%M-%S")

# DateTime in index umwandeln
dataset_15min_intervall.set_index("DateTime", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Datum und Zeitwert in datetime umwandeln
# ----> 2 dataset_15min_intervall["DateTime"] = pd.to_datetime(dataset_15min_intervall["DateTime"], utc=True)
#       4 # "Date" und "Time" als eigene Spalten erstellen
#       5 dataset_15min_intervall["Date"] = dataset_15min_intervall["DateTime"].dt.strftime("%Y-%m-%d")
#
# NameError: name 'pd' is not defined

# %%
# Datentyp ändern, Zeitwerte
dataset_15min_intervall["Date"] = pd.to_datetime(dataset_15min_intervall["Date"], format="%Y-%m-%d")
dataset_15min_intervall["Time"] = pd.to_datetime(dataset_15min_intervall["Time"], format="%H-%M-%S")

# %%
# Datentyp ändern, integers
int_cols = [
    "Jahr", "Monat", "Tag", "Wochentag", "Tag des Jahres",
    "Quartal", "Woche des Jahres",
]

for col in int_cols:
    dataset_15min_intervall[col] = pd.to_numeric(
        dataset_15min_intervall[col], errors="coerce"
    ).astype("Int64")

# %%
# Datentypen ändern, float64
float_cols = [
    'Stromverbrauch',
    'Lufttemperatur 2 m Ã¼. Boden',
    'Lufttemperatur 2 m Ã¼. Gras',
    'Lufttemperatur BodenoberflÃ¤che',
    'Chilltemperatur',
    'relative Luftfeuchtigkeit',
    'Taupunkt 2 m Ã¼. Boden',
    'Dampfdruck 2 m Ã¼. Boden ',
    'Luftrdruck auf BarometerhÃ¶he',
    'Luftdruck reduziert auf Meeresniveau mit StandardatmosphÃ¤re (QNH)',
    'Luftdruck reduziert auf Meeresniveau (QFF)',
    'BÃ¶enspitze (SekundenbÃ¶e)',
    'Windgeschwindigkeit vektoriell; Zehnminutenmittel in m/s',
    'Windgeschwindigkeit skalar; Zehnminutenmittel in m/s',
    'Windrichtung; Zehnminutenmittel',
    'Windgeschwindigkeit; Zehnminutenmittel in km/h',
    'BÃ¶enspitze (3-SekundenbÃ¶e); Maximum in m/s',
    'BÃ¶enspitze (SekundenbÃ¶e); Maximum in km/h',
    'BÃ¶enspitze (3-SekundenbÃ¶e); Maximum in km/h',
    'Niederschlag; Zehnminutensumme',
    'Globalstrahlung; Zehnminutenmittel',
    'Diffusstrahlung; Zehnminutenmittel',
    'Langwellige Einstrahlung; Zehnminutenmittel',
    'Sonnenscheindauer; Zehnminutensumme', 'Grundversorgte Kunden', 'Freie Kunden'
]

for col in float_cols:
    dataset_15min_intervall[col] = pd.to_numeric(dataset_15min_intervall[col], errors="coerce").astype("float64")

# %%
# Datentypen für KAtegoriale variablen
categorical_features = [
    "Jahr",
    "Monat",
    "Tag",
    "Wochentag",
    "Quartal",
    "Woche des Jahres"
]

for col in categorical_features:
    dataset_15min_intervall[col] = dataset_15min_intervall[col].astype("category")

# %% [markdown]
# ### Feature Selection

# %%
# Tag, Monat, und Jahr entfernt
dataset_15min_intervall.drop(["Jahr", "Monat","Tag"], axis=1)
# Out:
#                            Stromverbrauch  Grundversorgte Kunden  \
# DateTime
# 2011-12-31 23:15:00+00:00      33620.2025                    NaN
# 2011-12-31 23:30:00+00:00      33255.9075                    NaN
# 2011-12-31 23:45:00+00:00      32924.2950                    NaN
# 2012-01-01 00:00:00+00:00      32730.2850                    NaN
# 2012-01-01 00:15:00+00:00      32487.0300                    NaN
# ...                                   ...                    ...
# 2025-09-29 20:45:00+00:00      29913.4080              14750.099
# 2025-09-29 21:00:00+00:00      29071.5210              14044.536
# 2025-09-29 21:15:00+00:00      28417.0480              13554.318
# 2025-09-29 21:30:00+00:00      27710.9890              12977.944
# 2025-09-29 21:45:00+00:00      27314.7710              12713.834
#
#                            Freie Kunden Wochentag  Tag des Jahres Quartal  \
# DateTime
# 2011-12-31 23:15:00+00:00           NaN         6               1       1
# 2011-12-31 23:30:00+00:00           NaN         6               1       1
# 2011-12-31 23:45:00+00:00           NaN         6               1       1
# ...                                                       ...
# 2025-09-29 20:45:00+00:00                                 1.0
# 2025-09-29 21:00:00+00:00                                 1.0
# 2025-09-29 21:15:00+00:00                                 1.0
# 2025-09-29 21:30:00+00:00                                 1.0
# 2025-09-29 21:45:00+00:00                                 1.0
#
#                            Langwellige Einstrahlung; Zehnminutenmittel  \
# DateTime
# 2011-12-31 23:15:00+00:00                                        352.0
# 2011-12-31 23:30:00+00:00                                        349.5
# 2011-12-31 23:45:00+00:00                                        350.0
# 2012-01-01 00:00:00+00:00                                        350.5
# 2012-01-01 00:15:00+00:00                                        349.0
# ...                                                                ...
# 2025-09-29 20:45:00+00:00                                        230.0
# 2025-09-29 21:00:00+00:00                                        230.0
# 2025-09-29 21:15:00+00:00                                        230.0
# 2025-09-29 21:30:00+00:00                                        230.0
# 2025-09-29 21:45:00+00:00                                        230.0
#
#                            Sonnenscheindauer; Zehnminutensumme       Date  \
# DateTime
# 2011-12-31 23:15:00+00:00                                  0.0 2011-12-31
# 2011-12-31 23:30:00+00:00                                  0.0 2011-12-31
# 2011-12-31 23:45:00+00:00                                  0.0 2011-12-31
# 2012-01-01 00:00:00+00:00                                  0.0 2012-01-01
# 2012-01-01 00:15:00+00:00                                  0.0 2012-01-01
# ...                                                        ...        ...
# 2025-09-29 20:45:00+00:00                                  0.0 2025-09-29
# 2025-09-29 21:00:00+00:00                                  0.0 2025-09-29
# 2025-09-29 21:15:00+00:00                                  0.0 2025-09-29
# 2025-09-29 21:30:00+00:00                                  0.0 2025-09-29
# 2025-09-29 21:45:00+00:00                                  0.0 2025-09-29
#
#                                          Time
# DateTime
# 2011-12-31 23:15:00+00:00 1900-01-01 23:15:00
# 2011-12-31 23:30:00+00:00 1900-01-01 23:30:00
# 2011-12-31 23:45:00+00:00 1900-01-01 23:45:00
# 2012-01-01 00:00:00+00:00 1900-01-01 00:00:00
# 2012-01-01 00:15:00+00:00 1900-01-01 00:15:00
# ...                                       ...
# 2025-09-29 20:45:00+00:00 1900-01-01 20:45:00
# 2025-09-29 21:00:00+00:00 1900-01-01 21:00:00
# 2025-09-29 21:15:00+00:00 1900-01-01 21:15:00
# 2025-09-29 21:30:00+00:00 1900-01-01 21:30:00
# 2025-09-29 21:45:00+00:00 1900-01-01 21:45:00
#
# [481959 rows x 32 columns]

# %% [markdown]
# ### Feature Creation

# %%
# Spalte mit dem Tag im Jahr kreieren
#dataset_15min_intervall['DayOfYear'] = dataset_15min_intervall["DateTime"].dt.dayofyear
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Kerem Akkaya\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DateTime'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[133], line 2
#       1 # Spalte mit dem Tag im Jahr kreieren
# ----> 2 dataset_15min_intervall['DayOfYear'] = dataset_15min_intervall["DateTime"].dt.dayofyear
#
# File c:\Users\Kerem Akkaya\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\Kerem Akkaya\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'DateTime'
